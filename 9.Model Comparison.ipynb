# %% [markdown]
# # Model Comparison
#
# * Below is the final score comparison of all the models tried so far:
#
# | Models | Final Score | Kaggle Score |
# |----|----|----|
# | Baseline Model (CNN based) | 0.90428 | |
# | Baseline Model (CNN based) with word count feature | 0.89649 | |
# | Bi-directional LSTM (Architecture 1) | **0.9262** | **0.92482** |
# | Bi-directional LSTM (Architecture 2) | 0.91132 | 0.91295 |
# | Bi-directional LSTM with Attention Mechanism | 0.92058 | 0.91632 |
# | MLP with BERT Features | 0.86431 | 0.86048 |
# | MLP with BERT Features (Undersampled Data) | 0.83723 | 0.85678 |
# | Bi-directional LSTM with GloVe and BERT Features | 0.92369 | 0.92248 |

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# * Based on the highest score, we can choose the **Bi-directional LSTM Model (Architecture 1)** as the final model.

# %% [markdown]
# ----
